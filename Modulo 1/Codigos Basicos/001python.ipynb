# %% [markdown]
# #tutorial variaveis

# %% [markdown]
# ##o que são variáveis

# %% [markdown]
# Variáveis são espaços na memória do computador onde podemos armazenar informações (como textos, números, resultados de cáculos e etc) para usar depois

# %% [markdown]
# variável com texto (sting)

# %%
nome = "guilherme"
print(nome)
# Out:
# guilherme

# %%
nome = "roberto"
print (nome)
# Out:
# roberto

# %% [markdown]
# Variável com número inteiro (int)

# %%
idade = 16
print (idade)
# Out:
# 16

# %%
#este é um exemplo de um número inteiro negativo
temperatura = -3 #esta variável está armazenando um número negativo
print (temperatura) #print () é uma função de saída
# Out:
# -3

# %% [markdown]
# Variável com número decimal (float)

# %%
altura = 190 #em python os numeros decimais sao #escritos com".", exemplo=5,2
print (altura)
# Out:
# 190

# %%
pi = 3,14
print (pi)
# Out:
# (3, 14)

# %% [markdown]
# variavel com valor booleano (bool)

# %%
estudante = True
print (estudante)
# Out:
# True

# %% [markdown]
# ##Nome de variáveis

# %% [markdown]
# Pode:
# *comecar com letra exemplos (n, numero, altura)
# *conter numero, mas nao pode começar com numeros Exemplos (n1, numero 1, etc)
#
# Não pode:
# * começar com numero
# * usar espaço exemplo(nome_completo, nome-completo, nome completo)
# *usar acentuaçao ou caracteres especiais Exemplo(%, &, # e @)
# * usar palavras reservadas

# %%
 # ERRADO
 1idade = 16 #começar com número
 meu nome = "ana" #espaço não é permitido

# %% [markdown]
# ##O que é snake case
# snake_case é um estilo de escrita usado para nomes de variáveis, funçoes e nomes em gerais no codigo. neste estilo as palavras sao todas minusculas separadas por um underline (_)

# %% [markdown]
# ## por que usar snake_case ?
#
# * deixa o codigo mais facil de ler
# * e o padrao recomendado pela comunidade python
# * segue a PEF8 que e o guia de estilo oficial do python
#
# OBS: o PEF8 e um documento que regula as boas praticas para escrever codigo python limpo e legivel

# %% [markdown]
# ##Exemplos que não usam snake_case

# %%
nomeCompleto= "maria" #estilo camelcase (mais comum em java script)
NomeCompleto= "maria" #estilo pascalcase (mais comum em classes no python)
nomecompleto= "maria" #estilo dificil de ler
