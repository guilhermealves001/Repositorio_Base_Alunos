# %% [markdown]
# #Operadores relacionados

# %% [markdown]
# ##> maior
# ##>= Maior igual
# ##< menor
# ##<= menor igual
# ##!= Diferente
# ##== igual

# %%
10 > 20 # 10 é maior que 20
# Out:
# False

# %%
10 < 20 # 10 é menor que 20
# Out:
# True

# %%
5+1 != 4 # 5+1 é diferente de 6
# Out:
# True

# %%
3+1 >=4 #3+1 é maior ou igual a 4
# Out:
# True

# %% [markdown]
# #Operadores lógicos

# %% [markdown]
# * And (e)
# * Or (ou)
# * Not (negação)

# %%
(10<20) and (20>10)
# Out:
# True

# %% [markdown]
# # And
# *True + true = true
# *True + false = false
# *False + true = false
# *False + false = false

# %%
(10 > 20) and (20>20)
# Out:
# False

# %%
(10<20) and (20<30)
# Out:
# True

# %% [markdown]
# # Or
# *true + true = true
# *True + false = true
# *False + true = true
# *False + false + false

# %%
(1<2) or (3>6)
# Out:
# True

# %%
'Joao' == 'Joao' or 'Maria' != 'Maria'
# Out:
# True

# %% [markdown]
# #Not
# Not true = false not true = true

# %%
not true

# %%
not false

# %%
n1=5
n2=7
media=n1+n2
print(n1, n2, media)
# Out:
# 5 7 12
